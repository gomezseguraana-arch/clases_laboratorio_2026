# %%
## CARGAR UN ARCHIVO ".txt"
with open("nombres.txt", "r", encoding="utf-8") as f:
    contenido = f.read()

print(contenido)

# %%
## LECTURA LINEA POR LINEA E IMPRIME "*"
with open("nombres.txt", "r", encoding="utf-8") as f:
    for linea in f:
        print("*")
        print(linea.strip())

# %%
## LEER ARCHIVOS ".csv"
import pandas as pd

df = pd.read_csv("archivo.csv")
print(df.head())

# %%
import pandas as pd
print(pd.__version__)
# Out:
# La ejecución de celdas con 'Python 3.14.4' requiere el paquete ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Crear un entorno de Python</a> con los paquetes necesarios.
#
# O instale "ipykernel" mediante el comando: "c:/Users/gomez/.local/bin/python3.14.exe -m pip install ipykernel -U --user --force-reinstall"

# %%
## LEER ARCHIVOS CSV DESDE INTERNET
url = "https://example.com/datos.csv"
df = pd.read_csv(url)

# %%
## LEER ARCHICOS EXCEL ".xlsx"
pip install openpyxl
import pandas as pd

df = pd.read_excel("informe.xlsx")
print(df.head())

# %%
## ARCHIVOS DE FORMATO ".json"
import json

with open("archivo.json", "r", encoding="utf-8") as f:
    datos = json.load(f)

print(datos)
